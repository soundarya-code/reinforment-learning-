# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in g:\img_dect\tfod1\lib\site-packages (1.10.1)
# Requirement already satisfied: torchvision in g:\img_dect\tfod1\lib\site-packages (0.11.2)
# Requirement already satisfied: torchaudio in g:\img_dect\tfod1\lib\site-packages (0.10.1)
# Requirement already satisfied: typing-extensions in g:\img_dect\tfod1\lib\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in g:\img_dect\tfod1\lib\site-packages (from torchvision) (1.19.5)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in g:\img_dect\tfod1\lib\site-packages (from torchvision) (8.4.0)

# %%
# !pip install gym[box2d] pyglet
# !pip install gym[box2d] pyglet==1.3.2
# Out:
# Requirement already satisfied: gym[box2d] in g:\img_dect\tfod1\lib\site-packages (0.15.4)
# Requirement already satisfied: pyglet==1.3.2 in g:\img_dect\tfod1\lib\site-packages (1.3.2)
# Requirement already satisfied: future in g:\img_dect\tfod1\lib\site-packages (from pyglet==1.3.2) (0.18.2)
# Requirement already satisfied: six in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (1.15.0)
# Requirement already satisfied: numpy>=1.10.4 in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (1.19.5)
# Requirement already satisfied: opencv-python in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (4.5.4.60)
# Requirement already satisfied: scipy in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (1.7.3)
# Requirement already satisfied: cloudpickle~=1.2.0 in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (1.2.2)
# Requirement already satisfied: box2d-py~=2.3.5 in g:\img_dect\tfod1\lib\site-packages (from gym[box2d]) (2.3.8)

# %%
import gym 
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import VecFrameStack
from stable_baselines3.common.evaluation import evaluate_policy
import os
# Out:
# G:\img_dect\tfod1\lib\site-packages\setuptools\distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %%
environment_name = "CarRacing-v0"

# %%
# environment_name = "CarRacing-v0"
# # env = gym.make(environment_name)
env = gym.make(environment_name)

# %%
# !pip install pyvirtualdisplay
# !pip install PyOpenGL
# !pip install PyOpenGL-accelerate
# !pip install pyglet==1.3.2
# !pip install  pyglet --upgrade
# Out:
# Requirement already satisfied: pyvirtualdisplay in g:\img_dect\tfod1\lib\site-packages (2.2)
# Requirement already satisfied: EasyProcess in g:\img_dect\tfod1\lib\site-packages (from pyvirtualdisplay) (0.3)
# Requirement already satisfied: PyOpenGL in g:\img_dect\tfod1\lib\site-packages (3.1.5)
# Requirement already satisfied: PyOpenGL-accelerate in g:\img_dect\tfod1\lib\site-packages (3.1.5)

# %%
# !pip uninstall PyCrypto
# !pip install -U PyCryptodome
# Out:
# WARNING: Skipping PyCrypto as it is not installed.
# Requirement already satisfied: PyCryptodome in g:\img_dect\tfod1\lib\site-packages (3.12.0)

# %%
# env = gym.make(environment_name)
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0 
    
    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
env.close()
# Out:
# Track generation: 1015..1273 -> 258-tiles track
# Episode:1 Score:-22.17898832684847
# Track generation: 952..1201 -> 249-tiles track
# Episode:2 Score:-15.32258064516111
# Track generation: 1018..1284 -> 266-tiles track
# Episode:3 Score:-24.528301886792676
# Track generation: 1025..1285 -> 260-tiles track
# Episode:4 Score:-26.640926640926846
# Track generation: 1159..1488 -> 329-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1192..1494 -> 302-tiles track
# Episode:5 Score:-33.55481727574803

# %% [raw]
# #env.reset()

# %%
# episodes = 5
# for episode in range(1, episodes+1):
#     state = env.reset()
#     done = False
#     score = 0 
    
#     while not done:
#         env.render()
#         action,_ = env.action_space.sample()
#         n_state, reward, done, info = env.step(action)
#         score+=reward
#     print('Episode:{} Score:{}'.format(episode, score))
# env.close()

# %%
env.action_space.sample()
# Out:
# array([-0.30605483,  0.8721669 ,  0.705544  ], dtype=float32)

# %%
env.render()
# Out:
# True

# %%
log_path=os.path.join('training','log_path')

# %%
model=PPO('CnnPolicy',env,verbose=1,tensorboard_log=log_path)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=50000)
# Out:
# Track generation: 1278..1601 -> 323-tiles track
# Logging to training\log_path\PPO_24
# Track generation: 1179..1478 -> 299-tiles track
# Track generation: 1287..1613 -> 326-tiles track
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1e+03    |
# |    ep_rew_mean     | -58.1    |
# | time/              |          |
# |    fps             | 36       |
# |    iterations      | 1        |
# |    time_elapsed    | 55       |
# |    total_timesteps | 2048     |
# ---------------------------------
# Track generation: 1140..1429 -> 289-tiles track
# Track generation: 1093..1379 -> 286-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -56.9       |
# | time/                   |             |
# |    fps                  | 37          |
# |    iterations           | 2           |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.007839752 |
# |    clip_fraction        | 0.0873      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | -0.00755    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.207       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0097     |
# |    std                  | 0.987       |
# |    value_loss           | 0.558       |
# -----------------------------------------
# Track generation: 1258..1583 -> 325-tiles track
# Track generation: 1182..1482 -> 300-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.2       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 3           |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.012458948 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.0902      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.143       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0134     |
# |    std                  | 0.973       |
# |    value_loss           | 0.512       |
# -----------------------------------------
# Track generation: 1191..1493 -> 302-tiles track
# Track generation: 1195..1498 -> 303-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -52.2       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 4           |
# |    time_elapsed         | 211         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009795507 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.16       |
# |    explained_variance   | 0.0372      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.182       |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.965       |
# |    value_loss           | 0.577       |
# -----------------------------------------
# Track generation: 1250..1566 -> 316-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 5           |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014276134 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.474       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0767      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0196     |
# |    std                  | 0.956       |
# |    value_loss           | 0.369       |
# -----------------------------------------
# Track generation: 1371..1718 -> 347-tiles track
# Track generation: 1120..1404 -> 284-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 38          |
# |    iterations           | 6           |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.018514035 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.11       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.13        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 0.949       |
# |    value_loss           | 0.377       |
# -----------------------------------------
# Track generation: 1152..1449 -> 297-tiles track
# Track generation: 1180..1479 -> 299-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -42.4      |
# | time/                   |            |
# |    fps                  | 38         |
# |    iterations           | 7          |
# |    time_elapsed         | 367        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02040144 |
# |    clip_fraction        | 0.221      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.09      |
# |    explained_variance   | 0.509      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0853     |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.029     |
# |    std                  | 0.941      |
# |    value_loss           | 0.307      |
# ----------------------------------------
# Track generation: 1220..1529 -> 309-tiles track
# Track generation: 1040..1309 -> 269-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -40.7       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 8           |
# |    time_elapsed         | 419         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.018670272 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.494       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0274      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0292     |
# |    std                  | 0.928       |
# |    value_loss           | 0.431       |
# -----------------------------------------
# Track generation: 1015..1276 -> 261-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1046..1316 -> 270-tiles track
# Track generation: 1072..1350 -> 278-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -37.6       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 9           |
# |    time_elapsed         | 470         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.024502225 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.272       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0655      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.027      |
# |    std                  | 0.919       |
# |    value_loss           | 0.331       |
# -----------------------------------------
# Track generation: 1484..1859 -> 375-tiles track
# Track generation: 1128..1420 -> 292-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -41.3       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 10          |
# |    time_elapsed         | 521         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024610655 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | -0.351      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0365      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.906       |
# |    value_loss           | 0.456       |
# -----------------------------------------
# Track generation: 1092..1379 -> 287-tiles track
# Track generation: 1068..1339 -> 271-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -43.8      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 11         |
# |    time_elapsed         | 572        |
# |    total_timesteps      | 22528      |
# | train/                  |            |
# |    approx_kl            | 0.02505152 |
# |    clip_fraction        | 0.224      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.96      |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0277     |
# |    n_updates            | 100        |
# |    policy_gradient_loss | -0.0224    |
# |    std                  | 0.905      |
# |    value_loss           | 0.142      |
# ----------------------------------------
# Track generation: 984..1243 -> 259-tiles track
# Track generation: 1069..1346 -> 277-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -45.9       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 12          |
# |    time_elapsed         | 623         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.022902941 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.93       |
# |    explained_variance   | 0.63        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0211     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.89        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Track generation: 1082..1358 -> 276-tiles track
# Track generation: 1216..1524 -> 308-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -47.4       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 13          |
# |    time_elapsed         | 675         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.019271096 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0487     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0221     |
# |    std                  | 0.876       |
# |    value_loss           | 0.109       |
# -----------------------------------------
# Track generation: 1166..1461 -> 295-tiles track
# Track generation: 1155..1448 -> 293-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -48.6       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 14          |
# |    time_elapsed         | 727         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021225343 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0535     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.86        |
# |    value_loss           | 0.112       |
# -----------------------------------------
# Track generation: 1318..1651 -> 333-tiles track
# Track generation: 1131..1420 -> 289-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1171..1468 -> 297-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -49.4       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 15          |
# |    time_elapsed         | 779         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.037651315 |
# |    clip_fraction        | 0.302       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.795       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0412     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.042      |
# |    std                  | 0.851       |
# |    value_loss           | 0.159       |
# -----------------------------------------
# Track generation: 1202..1507 -> 305-tiles track
# Track generation: 1167..1471 -> 304-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -50.5       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 16          |
# |    time_elapsed         | 831         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.027064852 |
# |    clip_fraction        | 0.247       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00811    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.851       |
# |    value_loss           | 0.124       |
# -----------------------------------------
# Track generation: 975..1231 -> 256-tiles track
# Track generation: 1124..1409 -> 285-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -51.3       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 17          |
# |    time_elapsed         | 882         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.030016543 |
# |    clip_fraction        | 0.263       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0319     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.843       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1297..1625 -> 328-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -52.2      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 18         |
# |    time_elapsed         | 933        |
# |    total_timesteps      | 36864      |
# | train/                  |            |
# |    approx_kl            | 0.03945428 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.71      |
# |    explained_variance   | 0.893      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0348     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0289    |
# |    std                  | 0.826      |
# |    value_loss           | 0.139      |
# ----------------------------------------
# Track generation: 1174..1472 -> 298-tiles track
# Track generation: 1162..1464 -> 302-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1066..1337 -> 271-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -53.3       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 19          |
# |    time_elapsed         | 986         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.028135786 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0266     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0259     |
# |    std                  | 0.819       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# Track generation: 1125..1410 -> 285-tiles track
# Track generation: 1189..1497 -> 308-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -53.9      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 20         |
# |    time_elapsed         | 1037       |
# |    total_timesteps      | 40960      |
# | train/                  |            |
# |    approx_kl            | 0.03351195 |
# |    clip_fraction        | 0.299      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | 0.917      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0455     |
# |    n_updates            | 190        |
# |    policy_gradient_loss | -0.0205    |
# |    std                  | 0.818      |
# |    value_loss           | 0.132      |
# ----------------------------------------
# Track generation: 991..1249 -> 258-tiles track
# Track generation: 1123..1408 -> 285-tiles track
# Track generation: 1238..1552 -> 314-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 21          |
# |    time_elapsed         | 1088        |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.028348241 |
# |    clip_fraction        | 0.279       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0257     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0322     |
# |    std                  | 0.816       |
# |    value_loss           | 0.136       |
# -----------------------------------------
# Track generation: 1122..1406 -> 284-tiles track
# Track generation: 1059..1335 -> 276-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -54.7       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 22          |
# |    time_elapsed         | 1141        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.029534772 |
# |    clip_fraction        | 0.259       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0183     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0212     |
# |    std                  | 0.809       |
# |    value_loss           | 0.212       |
# -----------------------------------------
# Track generation: 1340..1679 -> 339-tiles track
# Track generation: 1162..1455 -> 293-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -55        |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 23         |
# |    time_elapsed         | 1193       |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.03290353 |
# |    clip_fraction        | 0.306      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0364    |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.034     |
# |    std                  | 0.797      |
# |    value_loss           | 0.186      |
# ----------------------------------------
# Track generation: 1001..1257 -> 256-tiles track
# retry to generate track (normal if there are not many of this messages)
# Track generation: 1252..1569 -> 317-tiles track
# Track generation: 1179..1477 -> 298-tiles track
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -55.3       |
# | time/                   |             |
# |    fps                  | 39          |
# |    iterations           | 24          |
# |    time_elapsed         | 1247        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.037508536 |
# |    clip_fraction        | 0.285       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00641     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0321     |
# |    std                  | 0.787       |
# |    value_loss           | 0.193       |
# -----------------------------------------
# Track generation: 1195..1498 -> 303-tiles track
# Track generation: 1124..1416 -> 292-tiles track
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1e+03      |
# |    ep_rew_mean          | -54.8      |
# | time/                   |            |
# |    fps                  | 39         |
# |    iterations           | 25         |
# |    time_elapsed         | 1300       |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.04795607 |
# |    clip_fraction        | 0.348      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.54      |
# |    explained_variance   | 0.961      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0403    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0432    |
# |    std                  | 0.792      |
# |    value_loss           | 0.095      |
# ----------------------------------------

# %%
ppo_path=os.path.join('training','saved Models','PPO_Driving_Models')
# model.save(ppo_path,env)

# %%
evaluate_policy(model,env,n_eval_episodes=10,render=True)
# Out:
# G:\img_dect\tfod1\lib\site-packages\stable_baselines3\common\evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Track generation: 1163..1458 -> 295-tiles track
# Track generation: 1079..1353 -> 274-tiles track
# Track generation: 1176..1474 -> 298-tiles track
# Track generation: 1264..1584 -> 320-tiles track
# Track generation: 1251..1568 -> 317-tiles track
# Track generation: 1181..1478 -> 297-tiles track
# Track generation: 1168..1464 -> 296-tiles track
# Track generation: 1092..1375 -> 283-tiles track
# Track generation: 1139..1428 -> 289-tiles track
# Track generation: 1148..1439 -> 291-tiles track
# Track generation: 1224..1534 -> 310-tiles track
# (16.761182320863007, 25.92279094846451)

# %%
model.save(ppo_path)
